# %%
from sklearn.base import BaseEstimator, TransformerMixin, ClassifierMixin
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
from sklearn.linear_model import ElasticNetCV, LassoLarsCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import make_pipeline, make_union
from sklearn.utils import check_array
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection
from sklearn.decomposition import PCA, FastICA
from sklearn.decomposition import TruncatedSVD
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import r2_score

from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import NMF
from sklearn.cluster import FeatureAgglomeration

from sklearn.ensemble import RandomForestRegressor
import random

random.seed(1234)

import warnings
warnings.filterwarnings('ignore')

# %%
class StackingEstimator(BaseEstimator, TransformerMixin):
    
    def __init__(self, estimator):
        self.estimator = estimator

    def fit(self, X, y=None, **fit_params):
        self.estimator.fit(X, y, **fit_params)
        return self
    
    def transform(self, X):
        X = check_array(X)
        X_transformed = np.copy(X)
        # add class probabilities as a synthetic feature
        if issubclass(self.estimator.__class__, ClassifierMixin) and hasattr(self.estimator, 'predict_proba'):
            X_transformed = np.hstack((self.estimator.predict_proba(X), X))

        # add class prediction as a synthetic feature
        X_transformed = np.hstack((np.reshape(self.estimator.predict(X), (-1, 1)), X_transformed))

        return X_transformed

# %%
train = pd.read_csv('C:\\Users\Admin\\Documents\\DL_course_project\\default_csv_files\\train.csv')
test = pd.read_csv('C:\\Users\Admin\\Documents\\DL_course_project\\default_csv_files\\test.csv')

# removing the outlier
train = train.loc[train['y'] < 170, :]

# %%
# function for auto encoder with a compressed components n_comp = 12
def neural_compression_v2(train, test):
    dataset = pd.concat([train.drop('y', axis=1), test], axis=0)
    ids = dataset['ID']
    dataset.drop('ID', axis=1, inplace=True)
    y_train = train['y']
    
    cat_vars = [c for c in dataset.columns if dataset[c].dtype == 'object']
    for c in cat_vars:
        t_data = pd.get_dummies(dataset[c], prefix=c)
        dataset = pd.concat([dataset, t_data], axis=1)

    dataset.drop(cat_vars, axis=1, inplace=True)

    train = dataset[:train.shape[0]]
    test = dataset[train.shape[0]:]

    print("one hot encoded train shape :: {}".format(train.shape))
    print("one hot encoded test shape :: {}".format(test.shape))
    
    ''' neural network compression code '''
    
    from tensorflow.keras.layers import Input, Dense
    from tensorflow.keras.models import Model

    init_dim = train.shape[1]

    input_row = Input(shape=(init_dim, ))
    encoded = Dense(512, activation='relu')(input_row)
    encoded = Dense(256, activation='relu')(encoded)
    encoded = Dense(128, activation='relu')(encoded)
    encoded = Dense(64, activation='relu')(encoded)
    encoded = Dense(32, activation='relu')(encoded)
    
    encoded = Dense(12, activation='relu')(encoded)
    
    decoded = Dense(32, activation='relu')(encoded)
    decoded = Dense(64, activation='relu')(decoded)
    decoded = Dense(128, activation='relu')(decoded)
    decoded = Dense(256, activation='relu')(decoded)
    decoded = Dense(512, activation='relu')(decoded)
    decoded = Dense(init_dim, activation='sigmoid')(decoded)

    autoencoder = Model(inputs=input_row, outputs=decoded)
    autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
    
    # Ensure the data is in float format
    train_values = train.values.astype('float32')
    test_values = test.values.astype('float32')
    
    autoencoder.fit(train_values, train_values,
                    batch_size=256,
                    shuffle=True, validation_data=(test_values, test_values), epochs=300)
    # compressing the data
    encoder = Model(inputs=input_row, outputs=encoded)
    train_compress = encoder.predict(train_values)
    test_compress = encoder.predict(test_values)

    # denoising the data
    denoised_train = autoencoder.predict(train_values)
    denoised_test = autoencoder.predict(test_values)
    
    return train_compress, test_compress, denoised_train, denoised_test

# %%
train_compress, test_compress, denoised_train, denoised_test = neural_compression_v2(train, test)
# Out:
# one hot encoded train shape :: (4208, 579)
# one hot encoded test shape :: (4209, 579)
# Epoch 1/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 2/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 3/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 4/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 5/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 6/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 7/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 8/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 9/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.6930 - val_loss: 0.6929
# Epoch 10/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 11/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 12/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 13/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 14/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 15/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 16/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 17/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 18/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 19/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.6929 - val_loss: 0.6929
# Epoch 20/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6929 - val_loss: 0.6928
# Epoch 21/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 22/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 23/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 24/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 25/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 26/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 27/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 28/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 29/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 30/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6928 - val_loss: 0.6928
# Epoch 31/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.6928 - val_loss: 0.6927
# Epoch 32/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 33/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 34/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 35/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 36/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 37/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 38/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 39/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 40/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 41/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 42/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6927 - val_loss: 0.6926
# Epoch 43/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 44/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 45/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 46/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 47/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 48/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 49/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 50/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 51/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 52/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6926 - val_loss: 0.6926
# Epoch 53/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 54/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 55/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 56/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 57/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 58/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 59/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 60/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 61/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 62/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6925 - val_loss: 0.6925
# Epoch 63/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.6925 - val_loss: 0.6924
# Epoch 64/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 65/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 66/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 67/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 68/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 69/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 70/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 71/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 72/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 73/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 74/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 75/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 76/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 77/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 78/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 79/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 80/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 81/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 82/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 83/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.6923 - val_loss: 0.6923
# Epoch 84/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6923 - val_loss: 0.6922
# Epoch 85/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 86/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 87/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 88/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 89/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 90/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 91/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 92/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 93/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 94/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6922 - val_loss: 0.6921
# Epoch 95/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 96/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 97/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 98/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 99/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 100/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 101/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 102/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 103/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 104/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 105/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 106/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 107/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 108/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 109/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 110/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 111/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 112/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 113/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 114/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6920 - val_loss: 0.6920
# Epoch 115/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.6920 - val_loss: 0.6919
# Epoch 116/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 117/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 118/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 119/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 120/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 121/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 122/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 123/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 124/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6919 - val_loss: 0.6919
# Epoch 125/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6919 - val_loss: 0.6918
# Epoch 126/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 127/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 128/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 129/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 130/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 131/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 132/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 133/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 134/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 135/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 136/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 137/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 138/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 139/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 140/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 141/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 142/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 143/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 144/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 145/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 146/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 147/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 148/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 149/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 150/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 151/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 152/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 153/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 154/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 155/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6916 - val_loss: 0.6916
# Epoch 156/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6916 - val_loss: 0.6915
# Epoch 157/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 158/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 159/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 160/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 161/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 162/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 163/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 164/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 165/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6915 - val_loss: 0.6915
# Epoch 166/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6915 - val_loss: 0.6914
# Epoch 167/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 168/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 169/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 170/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 171/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 172/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 173/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 174/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 175/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 176/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6914 - val_loss: 0.6914
# Epoch 177/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 178/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 179/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 180/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 181/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 182/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 183/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 184/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 185/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 186/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6913 - val_loss: 0.6913
# Epoch 187/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 188/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 189/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 190/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 191/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 192/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 193/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 194/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 195/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 196/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 197/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 198/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 199/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 200/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 201/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 202/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 203/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 204/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 205/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 206/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6911 - val_loss: 0.6911
# Epoch 207/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 208/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 209/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 210/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 211/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 212/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 213/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 214/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 215/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 216/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 217/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6910 - val_loss: 0.6909
# Epoch 218/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 219/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 220/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 221/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 222/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 223/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 224/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 225/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 226/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6909 - val_loss: 0.6909
# Epoch 227/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6909 - val_loss: 0.6908
# Epoch 228/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 229/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 230/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 231/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 232/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 233/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 234/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 235/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 236/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6908 - val_loss: 0.6908
# Epoch 237/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 238/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 239/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 240/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 241/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 242/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 243/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 244/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 245/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 246/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6907 - val_loss: 0.6907
# Epoch 247/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.6907 - val_loss: 0.6906
# Epoch 248/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 249/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 250/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 251/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 252/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 253/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 254/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 255/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 256/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6906 - val_loss: 0.6906
# Epoch 257/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6906 - val_loss: 0.6905
# Epoch 258/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 259/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 260/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 261/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 262/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 263/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 264/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 265/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 266/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6905 - val_loss: 0.6905
# Epoch 267/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 268/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 269/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 270/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 271/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 272/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 273/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 274/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 275/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 276/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6904 - val_loss: 0.6904
# Epoch 277/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 278/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 279/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 280/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 281/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 282/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 283/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 284/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 285/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 286/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 287/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 288/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 289/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 290/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 291/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 292/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 293/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 294/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 295/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 296/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6902 - val_loss: 0.6902
# Epoch 297/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6901 - val_loss: 0.6901
# Epoch 298/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6901 - val_loss: 0.6901
# Epoch 299/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6901 - val_loss: 0.6901
# Epoch 300/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6901 - val_loss: 0.6901
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# ===================================== mean of the y for the categorical replacement ========================
mean_x0 = train[['X0', 'y']].groupby(['X0'], as_index=False).mean()
mean_x0.columns = ['X0', 'mean_x0']
train = pd.merge(train, mean_x0, on='X0', how='outer')

mean_x1 = train[['X1', 'y']].groupby(['X1'], as_index=False).mean()
mean_x1.columns = ['X1', 'mean_x1']
train = pd.merge(train, mean_x1, on='X1', how='outer')

mean_x2 = train[['X2', 'y']].groupby(['X2'], as_index=False).mean()
mean_x2.columns = ['X2', 'mean_x2']
train = pd.merge(train, mean_x2, on='X2', how='outer')

mean_x3 = train[['X3', 'y']].groupby(['X3'], as_index=False).mean()
mean_x3.columns = ['X3', 'mean_x3']
train = pd.merge(train, mean_x3, on='X3', how='outer')

mean_x4 = train[['X4', 'y']].groupby(['X4'], as_index=False).mean()
mean_x4.columns = ['X4', 'mean_x4']
train = pd.merge(train, mean_x4, on='X4', how='outer')

mean_x5 = train[['X5', 'y']].groupby(['X5'], as_index=False).mean()
mean_x5.columns = ['X5', 'mean_x5']
train = pd.merge(train, mean_x5, on='X5', how='outer')

mean_x6 = train[['X6', 'y']].groupby(['X6'], as_index=False).mean()
mean_x6.columns = ['X6', 'mean_x6']
train = pd.merge(train, mean_x6, on='X6', how='outer')

mean_x8 = train[['X8', 'y']].groupby(['X8'], as_index=False).mean()
mean_x8.columns = ['X8', 'mean_x8']
train = pd.merge(train, mean_x8, on='X8', how='outer')

test = pd.merge(test, mean_x0, on='X0', how='left')
test['mean_x0'].fillna(test['mean_x0'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x1, on='X1', how='left')
test['mean_x1'].fillna(test['mean_x1'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x2, on='X2', how='left')
test['mean_x2'].fillna(test['mean_x2'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x3, on='X3', how='left')
test['mean_x3'].fillna(test['mean_x3'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x4, on='X4', how='left')
test['mean_x4'].fillna(test['mean_x4'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x5, on='X5', how='left')
test['mean_x5'].fillna(test['mean_x5'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x6, on='X6', how='left')
test['mean_x6'].fillna(test['mean_x6'].dropna().mean(), inplace=True)

test = pd.merge(test, mean_x8, on='X8', how='left')
test['mean_x8'].fillna(test['mean_x8'].dropna().mean(), inplace=True)

# %%
# ===================================== mean of the y for the categorical replacement ========================

for c in train.columns:
    if train[c].dtype == 'object':
        lbl = LabelEncoder()
        lbl.fit(list(train[c].values) + list(test[c].values))
        train[c] = lbl.transform(list(train[c].values))
        test[c] = lbl.transform(list(test[c].values))

# %%
# ============================================== One hot encoding local inc, LB decrease ========================
# y_train = train['y']
# dataset = pd.concat([train.drop('y', axis=1), test], axis=0)
# print(dataset.shape)
# for c in dataset.columns:
#     if dataset[c].dtype == 'object':
#         t = pd.get_dummies(dataset[c], prefix=c)
#         dataset = pd.concat([dataset, t], axis=1)

# dataset.drop([c for c in train.columns if train[c].dtype == 'object'], axis=1, inplace=True)
# train = dataset[:train.shape[0]]
# train['y'] = y_train
# test = dataset[train.shape[0]:]

# ============================================== One hot encoding local inc, LB decrease ========================

# %%
n_comp = 12

# tSVD
tsvd = TruncatedSVD(n_components=n_comp, random_state=420)
tsvd_results_train = tsvd.fit_transform(train.drop(["y"], axis=1))
tsvd_results_test = tsvd.transform(test)

# PCA
pca = PCA(n_components=n_comp, random_state=420)
pca2_results_train = pca.fit_transform(train.drop(["y"], axis=1))
pca2_results_test = pca.transform(test)

# ICA
ica = FastICA(n_components=n_comp, random_state=420)
ica2_results_train = ica.fit_transform(train.drop(["y"], axis=1))
ica2_results_test = ica.transform(test)

# GRP
grp = GaussianRandomProjection(n_components=n_comp, eps=0.1, random_state=420)
grp_results_train = grp.fit_transform(train.drop(["y"], axis=1))
grp_results_test = grp.transform(test)

# SRP
srp = SparseRandomProjection(n_components=n_comp, dense_output=True, random_state=420)
srp_results_train = srp.fit_transform(train.drop(["y"], axis=1))
srp_results_test = srp.transform(test)

# NMF
nmf = NMF(n_components=n_comp, init='nndsvdar', random_state=420)
nmf_results_train = nmf.fit_transform(train.drop(["y"], axis=1))
nmf_results_test = nmf.transform(test)

# FAG
fag = FeatureAgglomeration(n_clusters=n_comp, linkage='ward')
fag_results_train = fag.fit_transform(train.drop(["y"], axis=1))
fag_results_test = fag.transform(test)

usable_columns = list(set(train.columns) - set(['y']))

# %%
# Append decomposition components to datasets
for i in range(1, n_comp + 1):
    train['pca_' + str(i)] = pca2_results_train[:, i - 1]
    test['pca_' + str(i)] = pca2_results_test[:, i - 1]

    train['ica_' + str(i)] = ica2_results_train[:, i - 1]
    test['ica_' + str(i)] = ica2_results_test[:, i - 1]

    train['tsvd_' + str(i)] = tsvd_results_train[:, i - 1]
    test['tsvd_' + str(i)] = tsvd_results_test[:, i - 1]

    train['grp_' + str(i)] = grp_results_train[:, i - 1]
    test['grp_' + str(i)] = grp_results_test[:, i - 1]

    train['srp_' + str(i)] = srp_results_train[:, i - 1]
    test['srp_' + str(i)] = srp_results_test[:, i - 1]
    
    train['nmf_' + str(i)] = nmf_results_train[:, i - 1]
    test['nmf_' + str(i)] = nmf_results_test[:, i - 1]
    
#     train['fag_' + str(i)] = fag_results_train[:, i - 1]
#     test['fag_' + str(i)] = fag_results_test[:, i - 1]

for j in range(1, train_compress.shape[1]):
    train['aen_' + str(j)] = train_compress[:, j-1]
    test['aen_' + str(j)] = test_compress[:, j-1]

# %%
# usable_columns = list(set(train.columns) - set(['y']))

y_train = train['y'].values
y_mean = np.mean(y_train)
id_test = test['ID'].values
# finaltrainset and finaltestset are data to be used only the stacked model (does not contain PCA, SVD... arrays) 
finaltrainset = train[usable_columns].values
finaltestset = test[usable_columns].values


'''Train the xgb model then predict the test data'''
print('running ....... ')

xgb_params = {
    'n_trees': 520, 
    'eta': 0.0045,
    'max_depth': 4,
    'subsample': 0.93,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'base_score': y_mean, # base prediction = mean(target)
}
# NOTE: Make sure that the class is labeled 'class' in the data file

dtrain = xgb.DMatrix(train.drop('y', axis=1), y_train)
dtest = xgb.DMatrix(test)

num_boost_rounds = 1250
# train model
model = xgb.train(xgb_params, dtrain, num_boost_round=num_boost_rounds)
y_pred = model.predict(dtest)
# Out:
# running .......

# %%
'''Train the stacked models then predict the test data'''

stacked_pipeline = make_pipeline(
    StandardScaler(),
    StackingEstimator(estimator=LassoLarsCV()),
    StackingEstimator(estimator=GradientBoostingRegressor(
        learning_rate=0.001, loss="huber", max_depth=3, max_features=0.55, 
        min_samples_leaf=18, min_samples_split=14, subsample=0.7)),
    LassoLarsCV()
)

stacked_pipeline.fit(finaltrainset, y_train)
results = stacked_pipeline.predict(finaltestset)

'''R2 Score on the entire Train data when averaging'''

print('R2 score on train data:')
print(r2_score(y_train,stacked_pipeline.predict(finaltrainset)*0.2855 + model.predict(dtrain)*0.7145))
score = r2_score(y_train, model.predict(dtrain))
print("xgboost score : {}".format(score))


'''Save submission to csv file'''
sub = pd.DataFrame()
sub['ID'] = id_test
sub['y'] = y_pred*0.75 + results*0.25
sub.to_csv('submission_encoder.csv', index=False)
# Out:
# R2 score on train data:
# 0.684329115566432
# xgboost score : 0.704460246064864
